# %%
import requests
import numpy as np
import pandas as pd

# %%
company = 'GOOG'

# %%
demo = 'Your API Key'

# %%
IS = requests.get(f'https://financialmodelingprep.com/api/v3/income-statement/{company}?apikey={demo}').json()

# %%
IS[0]
# Out:
# {'date': '2019-12-31',
#  'symbol': 'GOOG',
#  'fillingDate': '2020-02-04',
#  'acceptedDate': '2020-02-03 21:03:59',
#  'period': 'FY',
#  'revenue': 161857000000,
#  'costOfRevenue': 71896000000,
#  'grossProfit': 89961000000,
#  'grossProfitRatio': 0.555805433191,
#  'researchAndDevelopmentExpenses': 26018000000,
#  'generalAndAdministrativeExpenses': 9551000000,
#  'sellingAndMarketingExpenses': 18464000000,
#  'otherExpenses': 5394000000,
#  'operatingExpenses': 54033000000,
#  'costAndExpenses': 127626000000,
#  'interestExpense': 100000000,
#  'depreciationAndAmortization': 11781000000,
#  'ebitda': 46012000000,
#  'ebitdaratio': 0.284275626016,
#  'operatingIncome': 34231000000,
#  'operatingIncomeRatio': 0.211489154006,
#  'totalOtherIncomeExpensesNet': 5394000000,
#  'incomeBeforeTax': 39625000000,
#  'incomeBeforeTaxRatio': 0.244814867445,
#  'incomeTaxExpense': 5282000000,
#  'netIncome': 34343000000,
#  'netIncomeRatio': 0.212181122843,
#  'eps': 49.59,
#  'epsdiluted': 49.16,
#  'weightedAverageShsOut': 346667000,
#  'weightedAverageShsOutDil': 352214000,
#  'link': 'https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/0001652044-20-000008-index.htm',
#  'finalLink': 'https://www.sec.gov/Archives/edgar/data/1652044/000165204420000008/goog10-k2019.htm'}

# %%
revenue_g = (IS[0]['revenue']-IS[1]['revenue']) / IS[1]['revenue']

# %%
net_income = IS[0]['netIncome']

# %%
BS = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{company}?apikey={demo}').json()

# %%
net_income
# Out:
# 34343000000

# %%
income_statement = pd.DataFrame.from_dict(IS[0], orient='index')

# %%
income_statement
# Out:
#                                                                                   0
# date                                                                     2019-12-31
# symbol                                                                         GOOG
# fillingDate                                                              2020-02-04
# acceptedDate                                                    2020-02-03 21:03:59
# period                                                                           FY
# revenue                                                                161857000000
# costOfRevenue                                                           71896000000
# grossProfit                                                             89961000000
# grossProfitRatio                                                           0.555805
# researchAndDevelopmentExpenses                                          26018000000
# generalAndAdministrativeExpenses                                         9551000000
# sellingAndMarketingExpenses                                             18464000000
# otherExpenses                                                            5394000000
# operatingExpenses                                                       54033000000
# costAndExpenses                                                        127626000000
# interestExpense                                                           100000000
# depreciationAndAmortization                                             11781000000
# ebitda                                                                  46012000000
# ebitdaratio                                                                0.284276
# operatingIncome                                                         34231000000
# operatingIncomeRatio                                                       0.211489
# totalOtherIncomeExpensesNet                                              5394000000
# incomeBeforeTax                                                         39625000000
# incomeBeforeTaxRatio                                                       0.244815
# incomeTaxExpense                                                         5282000000
# netIncome                                                               34343000000
# netIncomeRatio                                                             0.212181
# eps                                                                           49.59
# epsdiluted                                                                    49.16
# weightedAverageShsOut                                                     346667000
# weightedAverageShsOutDil                                                  352214000
# link                              https://www.sec.gov/Archives/edgar/data/165204...
# finalLink                         https://www.sec.gov/Archives/edgar/data/165204...

# %%
income_statement = income_statement[5:26]
income_statement.columns = ['current_year']

# %%
income_statement['as_%_of_revenue'] = income_statement / income_statement.iloc[0]
# Out:
# C:\Users\tulki\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
income_statement
# Out:
#                                   current_year as_%_of_revenue
# revenue                           161857000000               1
# costOfRevenue                      71896000000        0.444195
# grossProfit                        89961000000        0.555805
# grossProfitRatio                      0.555805     3.43393e-12
# researchAndDevelopmentExpenses     26018000000        0.160747
# generalAndAdministrativeExpenses    9551000000       0.0590089
# sellingAndMarketingExpenses        18464000000        0.114076
# otherExpenses                       5394000000       0.0333257
# operatingExpenses                  54033000000        0.333832
# costAndExpenses                   127626000000        0.788511
# interestExpense                      100000000     0.000617829
# depreciationAndAmortization        11781000000       0.0727865
# ebitda                             46012000000        0.284276
# ebitdaratio                           0.284276     1.75634e-12
# operatingIncome                    34231000000        0.211489
# operatingIncomeRatio                  0.211489     1.30664e-12
# totalOtherIncomeExpensesNet         5394000000       0.0333257
# incomeBeforeTax                    39625000000        0.244815
# incomeBeforeTaxRatio                  0.244815     1.51254e-12
# incomeTaxExpense                    5282000000       0.0326337
# netIncome                          34343000000        0.212181

# %%
#forecasting 5 next years income statement
income_statement['next_year'] =  (income_statement['current_year']['revenue'] * (1+revenue_g)) * income_statement['as_%_of_revenue'] 
income_statement['next_2_year'] =  (income_statement['next_year']['revenue'] * (1+revenue_g)) * income_statement['as_%_of_revenue'] 
income_statement['next_3_year'] =  (income_statement['next_2_year']['revenue'] * (1+revenue_g)) * income_statement['as_%_of_revenue'] 
income_statement['next_4_year'] =  (income_statement['next_3_year']['revenue'] * (1+revenue_g)) * income_statement['as_%_of_revenue'] 
income_statement['next_5_year'] =  (income_statement['next_4_year']['revenue'] * (1+revenue_g)) * income_statement['as_%_of_revenue']
# Out:
# C:\Users\tulki\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\tulki\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\tulki\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\tulki\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\tulki\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
income_statement
# Out:
#                                   current_year as_%_of_revenue    next_year  \
# revenue                           161857000000               1  1.91477e+11
# costOfRevenue                      71896000000        0.444195   8.5053e+10
# grossProfit                        89961000000        0.555805  1.06424e+11
# grossProfitRatio                      0.555805     3.43393e-12     0.657518
# researchAndDevelopmentExpenses     26018000000        0.160747  3.07793e+10
# generalAndAdministrativeExpenses    9551000000       0.0590089  1.12988e+10
# sellingAndMarketingExpenses        18464000000        0.114076  2.18429e+10
# otherExpenses                       5394000000       0.0333257  6.38111e+09
# operatingExpenses                  54033000000        0.333832  6.39211e+10
# costAndExpenses                   127626000000        0.788511  1.50982e+11
# interestExpense                      100000000     0.000617829    1.183e+08
# depreciationAndAmortization        11781000000       0.0727865  1.39369e+10
# ebitda                             46012000000        0.284276  5.44322e+10
# ebitdaratio                           0.284276     1.75634e-12     0.336298
# operatingIncome                    34231000000        0.211489  4.04953e+10
# operatingIncomeRatio                  0.211489     1.30664e-12     0.250192
# totalOtherIncomeExpensesNet         5394000000       0.0333257  6.38111e+09
# incomeBeforeTax                    39625000000        0.244815  4.68764e+10
# incomeBeforeTaxRatio                  0.244815     1.51254e-12     0.289616
# incomeTaxExpense                    5282000000       0.0326337  6.24861e+09
# netIncome                          34343000000        0.212181  4.06278e+10
#
#                                   next_2_year  next_3_year  next_4_year  \
# revenue                           2.26517e+11   2.6797e+11  3.17009e+11
# costOfRevenue                     1.00618e+11  1.19031e+11  1.40814e+11
# grossProfit                         1.259e+11  1.48939e+11  1.76195e+11
# grossProfitRatio                     0.777845     0.920191      1.08859
# researchAndDevelopmentExpenses     3.6412e+10  4.30754e+10  5.09582e+10
# generalAndAdministrativeExpenses  1.33665e+10  1.58126e+10  1.87064e+10
# sellingAndMarketingExpenses       2.58402e+10   3.0569e+10  3.61631e+10
# otherExpenses                     7.54886e+09   8.9303e+09  1.05646e+10
# operatingExpenses                 7.56187e+10   8.9457e+10  1.05828e+11
# costAndExpenses                   1.78611e+11  2.11298e+11  2.49965e+11
# interestExpense                   1.39949e+08   1.6556e+08  1.95858e+08
# depreciationAndAmortization       1.64874e+10  1.95046e+10   2.3074e+10
# ebitda                            6.43934e+10  7.61774e+10   9.0118e+10
# ebitdaratio                          0.397841     0.470647     0.556775
# operatingIncome                    4.7906e+10  5.66728e+10   6.7044e+10
# operatingIncomeRatio                 0.295977     0.350141     0.414217
# totalOtherIncomeExpensesNet       7.54886e+09   8.9303e+09  1.05646e+10
# incomeBeforeTax                   5.54548e+10  6.56031e+10  7.76086e+10
# incomeBeforeTaxRatio                 0.342616     0.405315     0.479488
# incomeTaxExpense                  7.39211e+09  8.74488e+09  1.03452e+10
# netIncome                         4.80627e+10  5.68582e+10  6.72634e+10
#
#                                   next_5_year
# revenue                           3.75022e+11
# costOfRevenue                     1.66583e+11
# grossProfit                       2.08439e+11
# grossProfitRatio                       1.2878
# researchAndDevelopmentExpenses    6.02836e+10
# generalAndAdministrativeExpenses  2.21296e+10
# sellingAndMarketingExpenses        4.2781e+10
# otherExpenses                     1.24979e+10
# operatingExpenses                 1.25194e+11
# costAndExpenses                   2.95709e+11
# interestExpense                     2.317e+08
# depreciationAndAmortization       2.72965e+10
# ebitda                             1.0661e+11
# ebitdaratio                          0.658666
# operatingIncome                   7.93131e+10
# operatingIncomeRatio                  0.49002
# totalOtherIncomeExpensesNet       1.24979e+10
# incomeBeforeTax                    9.1811e+10
# incomeBeforeTaxRatio                 0.567235
# incomeTaxExpense                  1.22384e+10
# netIncome                         7.95726e+10

# %%
balance_sheet = pd.DataFrame.from_dict(BS[0],orient='index')
balance_sheet
# Out:
#                                                                                          0
# date                                                                            2019-12-31
# symbol                                                                                GOOG
# fillingDate                                                                     2020-02-04
# acceptedDate                                                           2020-02-03 21:03:59
# period                                                                                  FY
# cashAndCashEquivalents                                                         18498000000
# shortTermInvestments                                                          101177000000
# cashAndShortTermInvestments                                                   119675000000
# netReceivables                                                                 25326000000
# inventory                                                                        999000000
# otherCurrentAssets                                                              6578000000
# totalCurrentAssets                                                            152578000000
# propertyPlantEquipmentNet                                                      10941000000
# goodwill                                                                       20624000000
# intangibleAssets                                                                1979000000
# goodwillAndIntangibleAssets                                                    22603000000
# longTermInvestments                                                            13078000000
# taxAssets                                                                        721000000
# otherNonCurrentAssets                                                          75988000000
# totalNonCurrentAssets                                                         123331000000
# otherAssets                                                                              0
# totalAssets                                                                   275909000000
# accountPayables                                                                 5561000000
# shortTermDebt                                                                    358000000
# taxPayables                                                                      274000000
# deferredRevenue                                                                 1908000000
# otherCurrentLiabilities                                                        37120000000
# totalCurrentLiabilities                                                        45221000000
# longTermDebt                                                                    4554000000
# deferredRevenueNonCurrent                                                        358000000
# deferredTaxLiabilitiesNonCurrent                                                1701000000
# otherNonCurrentLiabilities                                                      2534000000
# totalNonCurrentLiabilities                                                      9147000000
# otherLiabilities                                                               20099000000
# totalLiabilities                                                               74467000000
# commonStock                                                                          0.001
# retainedEarnings                                                              152122000000
# accumulatedOtherComprehensiveIncomeLoss                                        -1232000000
# othertotalStockholdersEquity                                                    5.0552e+10
# totalStockholdersEquity                                                       201442000000
# totalLiabilitiesAndStockholdersEquity                                         275909000000
# totalInvestments                                                              114255000000
# totalDebt                                                                       4912000000
# netDebt                                                                       -13586000000
# link                                     https://www.sec.gov/Archives/edgar/data/165204...
# finalLink                                https://www.sec.gov/Archives/edgar/data/165204...

# %%
balance_sheet = balance_sheet[5:-2]
balance_sheet.columns = ['current_year']
balance_sheet['as_%_of_revenue'] = balance_sheet / income_statement['current_year'].iloc[0]
# Out:
# C:\Users\tulki\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
balance_sheet
# Out:
#                                          current_year as_%_of_revenue
# cashAndCashEquivalents                    18498000000        0.114286
# shortTermInvestments                     101177000000        0.625101
# cashAndShortTermInvestments              119675000000        0.739387
# netReceivables                            25326000000        0.156471
# inventory                                   999000000      0.00617211
# otherCurrentAssets                         6578000000       0.0406408
# totalCurrentAssets                       152578000000        0.942672
# propertyPlantEquipmentNet                 10941000000       0.0675967
# goodwill                                  20624000000        0.127421
# intangibleAssets                           1979000000       0.0122268
# goodwillAndIntangibleAssets               22603000000        0.139648
# longTermInvestments                       13078000000       0.0807997
# taxAssets                                   721000000      0.00445455
# otherNonCurrentAssets                     75988000000        0.469476
# totalNonCurrentAssets                    123331000000        0.761975
# otherAssets                                         0               0
# totalAssets                              275909000000         1.70465
# accountPayables                            5561000000       0.0343575
# shortTermDebt                               358000000      0.00221183
# taxPayables                                 274000000      0.00169285
# deferredRevenue                            1908000000       0.0117882
# otherCurrentLiabilities                   37120000000        0.229338
# totalCurrentLiabilities                   45221000000        0.279389
# longTermDebt                               4554000000       0.0281359
# deferredRevenueNonCurrent                   358000000      0.00221183
# deferredTaxLiabilitiesNonCurrent           1701000000       0.0105093
# otherNonCurrentLiabilities                 2534000000       0.0156558
# totalNonCurrentLiabilities                 9147000000       0.0565128
# otherLiabilities                          20099000000        0.124178
# totalLiabilities                          74467000000        0.460079
# commonStock                                     0.001     6.17829e-15
# retainedEarnings                         152122000000        0.939854
# accumulatedOtherComprehensiveIncomeLoss   -1232000000     -0.00761166
# othertotalStockholdersEquity               5.0552e+10        0.312325
# totalStockholdersEquity                  201442000000         1.24457
# totalLiabilitiesAndStockholdersEquity    275909000000         1.70465
# totalInvestments                         114255000000        0.705901
# totalDebt                                  4912000000       0.0303478
# netDebt                                  -13586000000      -0.0839383

# %%
#forecasting the next 5 years Balance Sheet.
balance_sheet['next_year'] =  income_statement['next_year'] ['revenue'] * balance_sheet['as_%_of_revenue']
balance_sheet['next_2_year'] =  income_statement['next_2_year'] ['revenue'] * balance_sheet['as_%_of_revenue']
balance_sheet['next_3_year'] =  income_statement['next_3_year']['revenue'] * balance_sheet['as_%_of_revenue'] 
balance_sheet['next_4_year'] =  income_statement['next_4_year']['revenue']  * balance_sheet['as_%_of_revenue'] 
balance_sheet['next_5_year'] =  income_statement['next_5_year']['revenue'] * balance_sheet['as_%_of_revenue']
# Out:
# C:\Users\tulki\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\tulki\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\tulki\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\tulki\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\tulki\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
balance_sheet
# Out:
#                                          current_year as_%_of_revenue  \
# cashAndCashEquivalents                    18498000000        0.114286
# shortTermInvestments                     101177000000        0.625101
# cashAndShortTermInvestments              119675000000        0.739387
# netReceivables                            25326000000        0.156471
# inventory                                   999000000      0.00617211
# otherCurrentAssets                         6578000000       0.0406408
# totalCurrentAssets                       152578000000        0.942672
# propertyPlantEquipmentNet                 10941000000       0.0675967
# goodwill                                  20624000000        0.127421
# intangibleAssets                           1979000000       0.0122268
# goodwillAndIntangibleAssets               22603000000        0.139648
# longTermInvestments                       13078000000       0.0807997
# taxAssets                                   721000000      0.00445455
# otherNonCurrentAssets                     75988000000        0.469476
# totalNonCurrentAssets                    123331000000        0.761975
# otherAssets                                         0               0
# totalAssets                              275909000000         1.70465
# accountPayables                            5561000000       0.0343575
# shortTermDebt                               358000000      0.00221183
# taxPayables                                 274000000      0.00169285
# deferredRevenue                            1908000000       0.0117882
# otherCurrentLiabilities                   37120000000        0.229338
# totalCurrentLiabilities                   45221000000        0.279389
# longTermDebt                               4554000000       0.0281359
# deferredRevenueNonCurrent                   358000000      0.00221183
# deferredTaxLiabilitiesNonCurrent           1701000000       0.0105093
# otherNonCurrentLiabilities                 2534000000       0.0156558
# totalNonCurrentLiabilities                 9147000000       0.0565128
# otherLiabilities                          20099000000        0.124178
# totalLiabilities                          74467000000        0.460079
# commonStock                                     0.001     6.17829e-15
# retainedEarnings                         152122000000        0.939854
# accumulatedOtherComprehensiveIncomeLoss   -1232000000     -0.00761166
# othertotalStockholdersEquity               5.0552e+10        0.312325
# totalStockholdersEquity                  201442000000         1.24457
# totalLiabilitiesAndStockholdersEquity    275909000000         1.70465
# totalInvestments                         114255000000        0.705901
# totalDebt                                  4912000000       0.0303478
# netDebt                                  -13586000000      -0.0839383
#
#                                            next_year  next_2_year  \
# cashAndCashEquivalents                   2.18832e+10  2.58878e+10
# shortTermInvestments                     1.19692e+11  1.41596e+11
# cashAndShortTermInvestments              1.41576e+11  1.67484e+11
# netReceivables                           2.99607e+10  3.54435e+10
# inventory                                1.18182e+09  1.39809e+09
# otherCurrentAssets                       7.78178e+09  9.20585e+09
# totalCurrentAssets                         1.805e+11  2.13532e+11
# propertyPlantEquipmentNet                1.29432e+10  1.53118e+10
# goodwill                                 2.43982e+10  2.88631e+10
# intangibleAssets                         2.34116e+09  2.76959e+09
# goodwillAndIntangibleAssets              2.67394e+10  3.16327e+10
# longTermInvestments                      1.54713e+10  1.83025e+10
# taxAssets                                8.52944e+08  1.00903e+09
# otherNonCurrentAssets                    8.98939e+10  1.06345e+11
# totalNonCurrentAssets                    1.45901e+11  1.72601e+11
# otherAssets                                        0            0
# totalAssets                              3.26401e+11  3.86132e+11
# accountPayables                          6.57867e+09  7.78257e+09
# shortTermDebt                            4.23514e+08  5.01018e+08
# taxPayables                              3.24142e+08  3.83461e+08
# deferredRevenue                          2.25717e+09  2.67023e+09
# otherCurrentLiabilities                   4.3913e+10  5.19491e+10
# totalCurrentLiabilities                  5.34965e+10  6.32864e+10
# longTermDebt                             5.38739e+09  6.37328e+09
# deferredRevenueNonCurrent                4.23514e+08  5.01018e+08
# deferredTaxLiabilitiesNonCurrent         2.01228e+09  2.38053e+09
# otherNonCurrentLiabilities               2.99772e+09  3.54631e+09
# totalNonCurrentLiabilities               1.08209e+10  1.28011e+10
# otherLiabilities                         2.37771e+10  2.81284e+10
# totalLiabilities                         8.80945e+10  1.04216e+11
# commonStock                                 0.001183   0.00139949
# retainedEarnings                          1.7996e+11  2.12893e+11
# accumulatedOtherComprehensiveIncomeLoss -1.45746e+09 -1.72417e+09
# othertotalStockholdersEquity             5.98031e+10  7.07471e+10
# totalStockholdersEquity                  2.38306e+11  2.81916e+11
# totalLiabilitiesAndStockholdersEquity    3.26401e+11  3.86132e+11
# totalInvestments                         1.35164e+11  1.59899e+11
# totalDebt                                 5.8109e+09   6.8743e+09
# netDebt                                 -1.60723e+10 -1.90135e+10
#
#                                          next_3_year  next_4_year  next_5_year
# cashAndCashEquivalents                   3.06253e+10  3.62297e+10  4.28598e+10
# shortTermInvestments                     1.67509e+11  1.98163e+11  2.34427e+11
# cashAndShortTermInvestments              1.98134e+11  2.34393e+11  2.77287e+11
# netReceivables                           4.19297e+10  4.96029e+10  5.86803e+10
# inventory                                1.65394e+09  1.95662e+09  2.31468e+09
# otherCurrentAssets                       1.08905e+10  1.28835e+10  1.52412e+10
# totalCurrentAssets                       2.52608e+11  2.98836e+11  3.53523e+11
# propertyPlantEquipmentNet                1.81139e+10  2.14288e+10  2.53503e+10
# goodwill                                 3.41451e+10  4.03937e+10  4.77857e+10
# intangibleAssets                         3.27643e+09  3.87602e+09  4.58534e+09
# goodwillAndIntangibleAssets              3.74215e+10  4.42697e+10  5.23711e+10
# longTermInvestments                      2.16519e+10  2.56142e+10  3.03017e+10
# taxAssets                                1.19369e+09  1.41213e+09  1.67055e+09
# otherNonCurrentAssets                    1.25806e+11  1.48828e+11  1.76064e+11
# totalNonCurrentAssets                    2.04187e+11  2.41553e+11  2.85757e+11
# otherAssets                                        0            0            0
# totalAssets                              4.56795e+11  5.40389e+11   6.3928e+11
# accountPayables                          9.20679e+09  1.08916e+10  1.28848e+10
# shortTermDebt                            5.92705e+08   7.0117e+08  8.29485e+08
# taxPayables                              4.53634e+08   5.3665e+08  6.34857e+08
# deferredRevenue                          3.15888e+09  3.73696e+09  4.42083e+09
# otherCurrentLiabilities                  6.14558e+10  7.27023e+10  8.60069e+10
# totalCurrentLiabilities                  7.48679e+10  8.85687e+10  1.04777e+11
# longTermDebt                              7.5396e+09  8.91935e+09  1.05516e+10
# deferredRevenueNonCurrent                5.92705e+08   7.0117e+08  8.29485e+08
# deferredTaxLiabilitiesNonCurrent         2.81617e+09  3.33154e+09  3.94121e+09
# otherNonCurrentLiabilities               4.19529e+09  4.96303e+09  5.87127e+09
# totalNonCurrentLiabilities               1.51438e+10  1.79151e+10  2.11936e+10
# otherLiabilities                         3.32759e+10  3.93654e+10  4.65693e+10
# totalLiabilities                         1.23288e+11  1.45849e+11   1.7254e+11
# commonStock                                0.0016556   0.00195858     0.002317
# retainedEarnings                         2.51853e+11  2.97942e+11  3.52466e+11
# accumulatedOtherComprehensiveIncomeLoss  -2.0397e+09 -2.41296e+09 -2.85454e+09
# othertotalStockholdersEquity             8.36939e+10  9.90099e+10  1.17129e+11
# totalStockholdersEquity                  3.33507e+11  3.94539e+11   4.6674e+11
# totalLiabilitiesAndStockholdersEquity    4.56795e+11  5.40389e+11   6.3928e+11
# totalInvestments                          1.8916e+11  2.23777e+11  2.64728e+11
# totalDebt                                 8.1323e+09  9.62052e+09  1.13811e+10
# netDebt                                  -2.2493e+10 -2.66092e+10 -3.14787e+10

# %%
CF_forecast = {}

# %%
CF_forecast['next_year'] = {}

# %%
CF_forecast['next_year']['netIncome'] = income_statement['next_year']['netIncome']
CF_forecast['next_year']['inc_depreciation'] = income_statement['next_year']['depreciationAndAmortization'] - income_statement['current_year']['depreciationAndAmortization']
CF_forecast['next_year']['inc_receivables'] = balance_sheet['next_year']['netReceivables'] - balance_sheet['current_year']['netReceivables']
CF_forecast['next_year']['inc_inventory'] = balance_sheet['next_year']['inventory'] - balance_sheet['current_year']['inventory']
CF_forecast['next_year']['inc_payables'] = balance_sheet['next_year']['accountPayables'] - balance_sheet['current_year']['accountPayables']
CF_forecast['next_year']['CF_operations'] = CF_forecast['next_year']['netIncome'] + CF_forecast['next_year']['inc_depreciation'] + (CF_forecast['next_year']['inc_receivables'] * -1) + (CF_forecast['next_year']['inc_inventory'] *-1) + CF_forecast['next_year']['inc_payables']
CF_forecast['next_year']['CAPEX'] = balance_sheet['next_year']['propertyPlantEquipmentNet'] - balance_sheet['current_year']['propertyPlantEquipmentNet'] + income_statement['next_year']['depreciationAndAmortization']

# %%
CF_forecast
# Out:
# {'next_year': {'netIncome': 40627799874.28646,
#   'inc_depreciation': 2155933591.094803,
#   'inc_receivables': 4634680768.021984,
#   'inc_inventory': 182817898.09894824,
#   'inc_payables': 1017667999.3275776,
#   'CF_operations': 38983902798.58791,
#   'CAPEX': 15939146427.031332}}

# %%
CF_forecast['next_year']['FCF'] = CF_forecast['next_year']['CAPEX'] + CF_forecast['next_year']['CF_operations']

# %%
CF_forecast
# Out:
# {'next_year': {'netIncome': 40627799874.28646,
#   'inc_depreciation': 2155933591.094803,
#   'inc_receivables': 4634680768.021984,
#   'inc_inventory': 182817898.09894824,
#   'inc_payables': 1017667999.3275776,
#   'CF_operations': 38983902798.58791,
#   'CAPEX': 15939146427.031332,
#   'FCF': 54923049225.61925}}

# %%
CF_forecast['next_2_year'] = {}
CF_forecast['next_2_year']['netIncome'] = income_statement['next_2_year']['netIncome']

CF_forecast['next_2_year']['inc_depreciation'] = income_statement['next_2_year']['depreciationAndAmortization'] - income_statement['next_year']['depreciationAndAmortization']
CF_forecast['next_2_year']['inc_receivables'] = balance_sheet['next_2_year']['netReceivables'] - balance_sheet['next_year']['netReceivables']
CF_forecast['next_2_year']['inc_inventory'] = balance_sheet['next_2_year']['inventory'] - balance_sheet['next_year']['inventory']
CF_forecast['next_2_year']['inc_payables'] = balance_sheet['next_2_year']['accountPayables'] - balance_sheet['next_year']['accountPayables']
CF_forecast['next_2_year']['CF_operations'] = CF_forecast['next_2_year']['netIncome'] + CF_forecast['next_2_year']['inc_depreciation'] + (CF_forecast['next_2_year']['inc_receivables'] * -1) + (CF_forecast['next_2_year']['inc_inventory'] *-1) + CF_forecast['next_2_year']['inc_payables']
CF_forecast['next_2_year']['CAPEX'] = balance_sheet['next_2_year']['propertyPlantEquipmentNet'] - balance_sheet['next_year']['propertyPlantEquipmentNet'] + income_statement['next_2_year']['depreciationAndAmortization']
CF_forecast['next_2_year']['FCF'] = CF_forecast['next_2_year']['CAPEX'] + CF_forecast['next_2_year']['CF_operations']


CF_forecast['next_3_year'] = {}
CF_forecast['next_3_year']['netIncome'] = income_statement['next_3_year']['netIncome']

CF_forecast['next_3_year']['inc_depreciation'] = income_statement['next_3_year']['depreciationAndAmortization'] - income_statement['next_2_year']['depreciationAndAmortization']
CF_forecast['next_3_year']['inc_receivables'] = balance_sheet['next_3_year']['netReceivables'] - balance_sheet['next_2_year']['netReceivables']
CF_forecast['next_3_year']['inc_inventory'] = balance_sheet['next_3_year']['inventory'] - balance_sheet['next_2_year']['inventory']
CF_forecast['next_3_year']['inc_payables'] = balance_sheet['next_3_year']['accountPayables'] - balance_sheet['next_2_year']['accountPayables']
CF_forecast['next_3_year']['CF_operations'] = CF_forecast['next_3_year']['netIncome'] + CF_forecast['next_3_year']['inc_depreciation'] + (CF_forecast['next_3_year']['inc_receivables'] * -1) + (CF_forecast['next_3_year']['inc_inventory'] *-1) + CF_forecast['next_3_year']['inc_payables']
CF_forecast['next_3_year']['CAPEX'] = balance_sheet['next_3_year']['propertyPlantEquipmentNet'] - balance_sheet['next_2_year']['propertyPlantEquipmentNet'] + income_statement['next_3_year']['depreciationAndAmortization']
CF_forecast['next_3_year']['FCF'] = CF_forecast['next_3_year']['CAPEX'] + CF_forecast['next_3_year']['CF_operations']


CF_forecast['next_4_year'] = {}
CF_forecast['next_4_year']['netIncome'] = income_statement['next_4_year']['netIncome']

CF_forecast['next_4_year']['inc_depreciation'] = income_statement['next_4_year']['depreciationAndAmortization'] - income_statement['next_3_year']['depreciationAndAmortization']
CF_forecast['next_4_year']['inc_receivables'] = balance_sheet['next_4_year']['netReceivables'] - balance_sheet['next_3_year']['netReceivables']
CF_forecast['next_4_year']['inc_inventory'] = balance_sheet['next_4_year']['inventory'] - balance_sheet['next_3_year']['inventory']
CF_forecast['next_4_year']['inc_payables'] = balance_sheet['next_4_year']['accountPayables'] - balance_sheet['next_3_year']['accountPayables']
CF_forecast['next_4_year']['CF_operations'] = CF_forecast['next_4_year']['netIncome'] + CF_forecast['next_4_year']['inc_depreciation'] + (CF_forecast['next_4_year']['inc_receivables'] * -1) + (CF_forecast['next_4_year']['inc_inventory'] *-1) + CF_forecast['next_4_year']['inc_payables']
CF_forecast['next_4_year']['CAPEX'] = balance_sheet['next_4_year']['propertyPlantEquipmentNet'] - balance_sheet['next_3_year']['propertyPlantEquipmentNet'] + income_statement['next_4_year']['depreciationAndAmortization']
CF_forecast['next_4_year']['FCF'] = CF_forecast['next_4_year']['CAPEX'] + CF_forecast['next_4_year']['CF_operations']

CF_forecast['next_5_year'] = {}
CF_forecast['next_5_year']['netIncome'] = income_statement['next_5_year']['netIncome']

CF_forecast['next_5_year']['inc_depreciation'] = income_statement['next_5_year']['depreciationAndAmortization'] - income_statement['next_4_year']['depreciationAndAmortization']
CF_forecast['next_5_year']['inc_receivables'] = balance_sheet['next_5_year']['netReceivables'] - balance_sheet['next_4_year']['netReceivables']
CF_forecast['next_5_year']['inc_inventory'] = balance_sheet['next_5_year']['inventory'] - balance_sheet['next_4_year']['inventory']
CF_forecast['next_5_year']['inc_payables'] = balance_sheet['next_5_year']['accountPayables'] - balance_sheet['next_4_year']['accountPayables']
CF_forecast['next_5_year']['CF_operations'] = CF_forecast['next_5_year']['netIncome'] + CF_forecast['next_5_year']['inc_depreciation'] + (CF_forecast['next_5_year']['inc_receivables'] * -1) + (CF_forecast['next_5_year']['inc_inventory'] *-1) + CF_forecast['next_5_year']['inc_payables']
CF_forecast['next_5_year']['CAPEX'] = balance_sheet['next_5_year']['propertyPlantEquipmentNet'] - balance_sheet['next_4_year']['propertyPlantEquipmentNet'] + income_statement['next_5_year']['depreciationAndAmortization']
CF_forecast['next_5_year']['FCF'] = CF_forecast['next_5_year']['CAPEX'] + CF_forecast['next_5_year']['CF_operations']

# %%
#add the forecasted cash flows into a Pandas
CF_forec = pd.DataFrame.from_dict(CF_forecast,orient='columns')

#add below option to format the dataframe with thousand separators
pd.options.display.float_format = '{:,.0f}'.format

print(CF_forec)
# Out:
#                       next_year    next_2_year    next_3_year    next_4_year  \
# netIncome        40,627,799,874 48,062,723,776 56,858,245,435 67,263,355,465
# inc_depreciation  2,155,933,591  2,550,471,376  3,017,209,931  3,569,362,061
# inc_receivables   4,634,680,768  5,482,831,515  6,486,194,611  7,673,174,056
# inc_inventory       182,817,898    216,273,738    255,852,026    302,673,177
# inc_payables      1,017,667,999  1,203,902,158  1,424,217,335  1,684,850,388
# CF_operations    38,983,902,799 46,117,992,057 54,557,626,064 64,541,720,680
# CAPEX            15,939,146,427 18,856,024,552 22,306,693,997 26,388,839,052
# FCF              54,923,049,226 64,974,016,610 76,864,320,061 90,930,559,733
#
#                      next_5_year
# netIncome         79,572,609,985
# inc_depreciation   4,222,558,527
# inc_receivables    9,077,371,807
# inc_inventory        358,062,641
# inc_payables       1,993,179,524
# CF_operations     76,352,913,588
# CAPEX             31,218,020,322
# FCF              107,570,933,910

# %%
#add the forecasted cash flows into a Pandas
CF_forec = pd.DataFrame.from_dict(CF_forecast,orient='columns')

# %%
CF_forec
# Out:
#                       next_year    next_2_year    next_3_year    next_4_year  \
# netIncome        40,627,799,874 48,062,723,776 56,858,245,435 67,263,355,465
# inc_depreciation  2,155,933,591  2,550,471,376  3,017,209,931  3,569,362,061
# inc_receivables   4,634,680,768  5,482,831,515  6,486,194,611  7,673,174,056
# inc_inventory       182,817,898    216,273,738    255,852,026    302,673,177
# inc_payables      1,017,667,999  1,203,902,158  1,424,217,335  1,684,850,388
# CF_operations    38,983,902,799 46,117,992,057 54,557,626,064 64,541,720,680
# CAPEX            15,939,146,427 18,856,024,552 22,306,693,997 26,388,839,052
# FCF              54,923,049,226 64,974,016,610 76,864,320,061 90,930,559,733
#
#                      next_5_year
# netIncome         79,572,609,985
# inc_depreciation   4,222,558,527
# inc_receivables    9,077,371,807
# inc_inventory        358,062,641
# inc_payables       1,993,179,524
# CF_operations     76,352,913,588
# CAPEX             31,218,020,322
# FCF              107,570,933,910

# %%
#add below option to format the dataframe with thousand separators
pd.options.display.float_format = '{:,.0f}'.format

# %%
CF_forec
# Out:
#                       next_year    next_2_year    next_3_year    next_4_year  \
# netIncome        40,627,799,874 48,062,723,776 56,858,245,435 67,263,355,465
# inc_depreciation  2,155,933,591  2,550,471,376  3,017,209,931  3,569,362,061
# inc_receivables   4,634,680,768  5,482,831,515  6,486,194,611  7,673,174,056
# inc_inventory       182,817,898    216,273,738    255,852,026    302,673,177
# inc_payables      1,017,667,999  1,203,902,158  1,424,217,335  1,684,850,388
# CF_operations    38,983,902,799 46,117,992,057 54,557,626,064 64,541,720,680
# CAPEX            15,939,146,427 18,856,024,552 22,306,693,997 26,388,839,052
# FCF              54,923,049,226 64,974,016,610 76,864,320,061 90,930,559,733
#
#                      next_5_year
# netIncome         79,572,609,985
# inc_depreciation   4,222,558,527
# inc_receivables    9,077,371,807
# inc_inventory        358,062,641
# inc_payables       1,993,179,524
# CF_operations     76,352,913,588
# CAPEX             31,218,020,322
# FCF              107,570,933,910

# %% [markdown]
# Calculate WACC

# %%
import pandas_datareader.data as web
import datetime
import requests


#demo = 'your api key'
#Interest coverage ratio = EBIT / interest expenses

def interest_coveraga_and_RF(company):
  IS= requests.get(f'https://financialmodelingprep.com/api/v3/income-statement/{company}?apikey={demo}').json()
  EBIT= IS[0]['ebitda'] - IS[0]['depreciationAndAmortization'] 
  interest_expense = IS[0]['interestExpense']
  interest_coverage_ratio = EBIT / interest_expense

    #RF
  start = datetime.datetime(2019, 7, 10)
        
  #end= datetime.datetime.today().strftime('%Y-%m-%d')
  end = datetime.datetime(2020, 7, 10)

  Treasury = web.DataReader(['TB1YR'], 'fred', start, end)
  RF = float(Treasury.iloc[-1])
  RF = RF/100
  return [RF,interest_coverage_ratio]
  
#Cost of debt
def cost_of_debt(company, RF,interest_coverage_ratio):
  if interest_coverage_ratio > 8.5:
    #Rating is AAA
    credit_spread = 0.0063
  if (interest_coverage_ratio > 6.5) & (interest_coverage_ratio <= 8.5):
    #Rating is AA
    credit_spread = 0.0078
  if (interest_coverage_ratio > 5.5) & (interest_coverage_ratio <=  6.5):
    #Rating is A+
    credit_spread = 0.0098
  if (interest_coverage_ratio > 4.25) & (interest_coverage_ratio <=  5.49):
    #Rating is A
    credit_spread = 0.0108
  if (interest_coverage_ratio > 3) & (interest_coverage_ratio <=  4.25):
    #Rating is A-
    credit_spread = 0.0122
  if (interest_coverage_ratio > 2.5) & (interest_coverage_ratio <=  3):
    #Rating is BBB
    credit_spread = 0.0156
  if (interest_coverage_ratio > 2.25) & (interest_coverage_ratio <=  2.5):
    #Rating is BB+
    credit_spread = 0.02
  if (interest_coverage_ratio > 2) & (interest_coverage_ratio <=  2.25):
    #Rating is BB
    credit_spread = 0.0240
  if (interest_coverage_ratio > 1.75) & (interest_coverage_ratio <=  2):
    #Rating is B+
    credit_spread = 0.0351
  if (interest_coverage_ratio > 1.5) & (interest_coverage_ratio <=  1.75):
    #Rating is B
    credit_spread = 0.0421
  if (interest_coverage_ratio > 1.25) & (interest_coverage_ratio <=  1.5):
    #Rating is B-
    credit_spread = 0.0515
  if (interest_coverage_ratio > 0.8) & (interest_coverage_ratio <=  1.25):
    #Rating is CCC
    credit_spread = 0.0820
  if (interest_coverage_ratio > 0.65) & (interest_coverage_ratio <=  0.8):
    #Rating is CC
    credit_spread = 0.0864
  if (interest_coverage_ratio > 0.2) & (interest_coverage_ratio <=  0.65):
    #Rating is C
    credit_spread = 0.1134
  if interest_coverage_ratio <=  0.2:
    #Rating is D
    credit_spread = 0.1512
  
  cost_of_debt = RF + credit_spread
  return cost_of_debt


def costofequity(company):


  #RF
  start = datetime.datetime(2019, 7, 10)
  end= datetime.datetime.today().strftime('%Y-%m-%d')
  #end = datetime.datetime(2020, 7, 10)

  Treasury = web.DataReader(['TB1YR'], 'fred', start, end)
  RF = float(Treasury.iloc[-1])
  RF = RF/100

#Beta

  beta = requests.get(f'https://financialmodelingprep.com/api/v3/company/profile/{company}?apikey={demo}')
  beta = beta.json()
  beta = float(beta['profile']['beta'])


  #Market Return
  start = datetime.datetime(2019, 7, 10)
  end= datetime.datetime.today().strftime('%Y-%m-%d')

  SP500 = web.DataReader(['sp500'], 'fred', start, end)
      #Drop all Not a number values using drop method.
  SP500.dropna(inplace = True)

  SP500yearlyreturn = (SP500['sp500'].iloc[-1]/ SP500['sp500'].iloc[-252])-1
    
  cost_of_equity = RF+(beta*(SP500yearlyreturn - RF))
  return cost_of_equity

#effective tax rate and capital structure
def wacc(company):
  FR = requests.get(f'https://financialmodelingprep.com/api/v3/ratios/{company}?apikey={demo}').json()

  ETR = FR[0]['effectiveTaxRate']

# 
  BS = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{company}?period=quarter&apikey={demo}').json()



  Debt_to = BS[0]['totalDebt'] / (BS[0]['totalDebt'] + BS[0]['totalStockholdersEquity'])
  equity_to = BS[0]['totalStockholdersEquity'] / (BS[0]['totalDebt'] + BS[0]['totalStockholdersEquity'])

  WACC = (kd*(1-ETR)*Debt_to) + (ke*equity_to)
  return WACC

RF_and_IntCov = interest_coveraga_and_RF(company)
RF = RF_and_IntCov[0]
interest_coverage_ratio = RF_and_IntCov[1]
ke = costofequity(company)
kd = cost_of_debt(company,RF,interest_coverage_ratio)
wacc_company = wacc(company)
print('wacc of ' + company + ' is ' + str((wacc_company*100))+'%')
# Out:
# wacc of GOOG is 11.119169508073801%

# %%
FCF_list = CF_forec.iloc[-1].values.tolist()

# %%
FCF_list
# Out:
# [54923049225.61925,
#  64974016609.616005,
#  76864320060.68323,
#  90930559732.65411,
#  107570933910.11627]

# %%
npv = np.npv(wacc_company, FCF_list)
# Out:
# C:\Users\tulki\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: numpy.npv is deprecated and will be removed from NumPy 1.20. Use numpy_financial.npv instead (https://pypi.org/project/numpy-financial/).
#   """Entry point for launching an IPython kernel.

# %%
npv
# Out:
# 312477268910.6243

# %%
#Terminal value
LTGrowth = 0.02

Terminal_value = (CF_forecast['next_5_year']['FCF'] * (1+ LTGrowth)) /(wacc_company  - LTGrowth)

Terminal_value_Discounted = Terminal_value/(1+wacc_company)**4
Terminal_value_Discounted
# Out:
# 789194181876.1213

# %%
target_equity_value = Terminal_value_Discounted + npv
debt = balance_sheet['current_year']['totalDebt']
target_value = target_equity_value - debt
target_value
# Out:
# 1096759450786.7456

# %%
numbre_of_shares = requests.get(f'https://financialmodelingprep.com/api/v3/enterprise-values/{company}?apikey={demo}').json()
numbre_of_shares = numbre_of_shares[0]['numberOfShares']

target_price_per_share = target_value/numbre_of_shares
target_price_per_share
# Out:
# 3163.726142917398

# %%
print(company + ' forecasted price per stock is ' + str(target_price_per_share) )
print('the forecast is based on the following assumptions: '+ 'revenue growth: ' + str(revenue_g) + ' Cost of Capital: ' + str(wacc_company) )
print('perpetuity growth: ' + str(LTGrowth)  )

#outcome
# GOOG forecasted price per stock is 4828.474984873333
# the forecast is based on the following assumptions: revenue growth: 0.15469210475913925 Cost of Capital: 0.07348998226517206
# perpetuity growth: 0.02
# Out:
# GOOG forecasted price per stock is 3163.726142917398
# the forecast is based on the following assumptions: revenue growth: 0.1830008989979462 Cost of Capital: 0.111191695080738
# perpetuity growth: 0.02
